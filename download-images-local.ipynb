# %%
import os
import pandas as pd
import requests

# %%
# Path to CSV file
csv_file = r'C:/Users/lakha/OneDrive/Documents/House Flipping - Real Life/HouseFlipping/image_links.csv'

# Directory to store images
output_directory = r'C:/Users/lakha/OneDrive/Documents/House Flipping - Real Life/HouseFlipping/Sold-House-Images'

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(csv_file)
len(df)
# Out:
# 276

# %%
# Create the output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Iterate through each row in the DataFrame
for index, row in df.iterrows():
    listing_number = str(row['listing_number'])  # Convert listing_number to string
    image_url = row['image_url']

    # Create directory for the current listing_number if it doesn't exist
    listing_directory = os.path.join(output_directory, listing_number)
    if not os.path.exists(listing_directory):
        os.makedirs(listing_directory)

    # Extract the image filename from the URL
    image_filename = os.path.basename(image_url)

    # Determine the path where the image will be saved
    save_path = os.path.join(listing_directory, image_filename)

    # Download the image from the URL
    response = requests.get(image_url)
    if response.status_code == 200:
        # Save the image to the specified path
        with open(save_path, 'wb') as f:
            f.write(response.content)
        print(f"Saved image {image_filename} for listing {listing_number}")
    else:
        print(f"Failed to download image {image_filename} for listing {listing_number}")
# Out:
# Saved image property-9906970-21822030_e.jpg for listing T4344130
# Saved image property-10203741-63224349_e.jpg for listing T4515204
# Saved image property-9906970-89917444_e.jpg for listing T4344130
# Saved image property-9906970-10485874_e.jpg for listing T4344130
# Saved image property-9906970-65757989_e.jpg for listing T4344130
# Saved image property-9906970-85753151_e.jpg for listing T4344130
# Saved image property-9906970-83533015_e.jpg for listing T4344130
# Saved image property-9906970-85987587_e.jpg for listing T4344130
# Saved image property-9906970-15065339_e.jpg for listing T4344130
# Saved image property-9906970-80906477_e.jpg for listing T4344130
# Saved image property-9906970-77060831_e.jpg for listing T4344130
# Saved image property-9906970-61539391_e.jpg for listing T4344130
# Saved image property-9906970-3846942_e.jpg for listing T4344130
# Saved image property-9906970-76735755_e.jpg for listing T4344130
# ...
